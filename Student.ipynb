# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# import jtplot module in notebook
from jupyterthemes import jtplot

# choose which theme to inherit plotting style from
# onedork | grade3 | oceans16 | chesterish | monokai | solarizedl | solarizedd
jtplot.style(theme='onedork')

# %%
df = pd.read_csv("StudentsPerformance2.csv")

# %%
df
# Out:
#      gender     race              parent         lunch  test_prep  math  \
# 0    female  group B   bachelor's degree      standard       none    72
# 1    female  group C        some college      standard  completed    69
# 2    female  group B     master's degree      standard       none    90
# 3      male  group A  associate's degree  free/reduced       none    47
# 4      male  group C        some college      standard       none    76
# 5    female  group B  associate's degree      standard       none    71
# 6    female  group B        some college      standard  completed    88
# 7      male  group B        some college  free/reduced       none    40
# 8      male  group D         high school  free/reduced  completed    64
# 9    female  group B         high school  free/reduced       none    38
# 10     male  group C  associate's degree      standard       none    58
# 11     male  group D  associate's degree      standard       none    40
# ...

# %%
x0 = 0
x40 = 40

# %%
missing_values = list(range(x0,x40+1))
df = pd.read_csv("StudentsPerformance2.csv", na_values = missing_values)

# %%
print (df['math'])
print (df['math'].isnull())
# Out:
# 0      72.0
# 1      69.0
# 2      90.0
# 3      47.0
# 4      76.0
# 5      71.0
# 6      88.0
# 7       NaN
# 8      64.0
# 9       NaN
# 10     58.0
# 11      NaN
# 12     65.0
# 13     78.0
# 14     50.0
# 15     69.0
# 16     88.0
# 17      NaN
# 18     46.0
# 19     54.0
# 20     66.0
# 21     65.0
# 22     44.0
# 23     69.0
# 24     74.0
# 25     73.0
# 26     69.0
# 27     67.0
# 28     70.0
# 29     62.0
#        ...
# 970    89.0
# 971    78.0
# 972    53.0
# 973    49.0
# 974    54.0
# 975    64.0
# 976    60.0
# 977    62.0
# 978    55.0
# 979    91.0
# 980     NaN
# 981    81.0
# 982    79.0
# 983    78.0
# 984    74.0
# 985    57.0
# 986     NaN
# 987    81.0
# 988    44.0
# 989    67.0
# 990    86.0
# 991    65.0
# 992    55.0
# 993    62.0
# 994    63.0
# 995    88.0
# 996    62.0
# 997    59.0
# 998    68.0
# 999    77.0
# Name: math, Length: 1000, dtype: float64
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# ...

# %%
print (df.isnull().values.any())
# Out:
# True

# %%
print (df.isnull().sum().sum())
# Out:
# 112

# %%
df['math'].fillna(40, inplace=True)

# %%
print (df.isnull().sum().sum())
# Out:
# 62

# %%
print (df.isnull().values.any())
# Out:
# True

# %%
df['reading'].fillna(40, inplace=True)

# %%
print (df.isnull().sum().sum())
# Out:
# 35

# %%
print (df.isnull().values.any())
# Out:
# True

# %%
df['writing'].fillna(40, inplace=True)

# %%
print (df.isnull().sum().sum())
# Out:
# 0

# %%
print (df.isnull().values.any())
# Out:
# False

# %%
print (df.isnull().values.any())
# Out:
# False

# %%
female = df[df.gender == 'female']

# %%
male = df[df.gender == 'male']

# %%
plt.plot(male.writing, "o")
plt.plot(female.writing, "o")
plt.title("Writing Score Based on Gender")
plt.legend(['Male', 'Female'])
plt.xlabel("NIM")
plt.ylabel("Nilai")
plt.show()

# %%
plt.plot(male.reading, "o")
plt.plot(female.reading, "o")
plt.title("Reading Score Based on Gender")
plt.legend(['Male', 'Female'])
plt.xlabel("NIM")
plt.ylabel("Nilai")
plt.show()

# %%
plt.plot(male.math, "o")
plt.plot(female.math, "o")
plt.title("Math Score Based on Gender")
plt.legend(['Male', 'Female'])
plt.xlabel("NIM")
plt.ylabel("Nilai")
plt.show()

# %%
avgmathmale = sum(male.math) / float(len(male.math))

# %%
avgmathfemale = sum(female.math) / float(len(female.math))

# %%
avgmathmale
# Out:
# 68.850622406639

# %%
avgmathfemale
# Out:
# 64.23166023166023

# %% [markdown]
# avgreadmale = sum(male.reading) / float(len(male.reading))

# %%
avgreadmale = sum(male.reading) / float(len(male.reading))

# %%
avgreadfemale = sum(female.reading) / float(len(female.reading))

# %%
avgreadmale
# Out:
# 65.68879668049793

# %%
avgreadfemale
# Out:
# 72.77220077220078

# %%
avgread = (avgreadmale + avgreadfemale) / 2

# %%
avgread
# Out:
# 69.23049872634935

# %%
avgmath = (avgmathmale + avgmathfemale) / 2

# %%
avgwritemale = sum(male.writing) / float(len(male.writing))

# %%
avgwritefemale = sum(female.writing) / float(len(female.writing))

# %%
avgwrite = (avgwritemale +avgwritefemale) / 2

# %%
avgwrite
# Out:
# 68.1510717890386

# %%
avgmath
# Out:
# 66.54114131914962

# %%
avgread
# Out:
# 69.23049872634935

# %%
A = df[df.race == 'group A']

# %%
B = df[df.race == 'group B']

# %%
C = df[df.race == 'group C']

# %%
D = df[df.race == 'group D']

# %%
plt.plot(A.math, "*")
plt.plot(B.math, "*")
plt.plot(C.math, "*")
plt.plot(D.math, "*")
plt.title("Math Score Based on Race")
plt.legend(['A', 'B', 'C', 'D'])
plt.xlabel("NIM")
plt.ylabel("Nilai")
plt.show()

# %%
plt.plot(A.math, ".")
plt.plot(B.math, ".")
plt.plot(C.math, ".")
plt.plot(D.math, ".")
plt.title("Math Score Based on Race")
plt.legend(['A', 'B', 'C', 'D'])
plt.xlabel("NIM")
plt.ylabel("Nilai")
plt.show()

# %%
HS = df[df.parent == 'high school']

# %%
SC = df[df.parent == 'some college']

# %%
AD = df[df.parent == "associate's degree"]

# %%
BD = df[df.parent == "bachelor's degree"]

# %%
MD = df[df.parent == "master's degree"]

# %%
plt.plot(HS.math, "*")
plt.plot(SC.math, "*")
plt.plot(AD.math, "*")
plt.plot(BD.math, "*")
plt.plot(MD.math, "*")
plt.title("Math Score Based on Parent's Education")
plt.legend(['High School', 'Some College', 'Associate', 'Bachelor', 'Master'])
plt.xlabel("NIM")
plt.ylabel("Nilai")
plt.show()

# %%
x1 = 61

# %%
x2 =100

# %%
lulus = list(range(x1,x2+1))

# %%
lulus
# Out:
# [61,
#  62,
#  63,
#  64,
#  65,
#  66,
#  67,
#  68,
#  69,
#  70,
#  71,
#  72,
#  73,
#  74,
#  75,
#  76,
#  77,
#  78,
#  79,
#  80,
#  81,
#  82,
#  83,
#  84,
#  85,
#  86,
#  87,
#  88,
#  89,
#  90,
#  91,
#  92,
#  93,
#  94,
#  95,
#  96,
#  97,
#  98,
#  99,
#  100]

# %%
passmath = df.loc[df['math'].isin(lulus)]

# %%
passmath
# Out:
#      gender     race              parent         lunch  test_prep   math  \
# 0    female  group B   bachelor's degree      standard       none   72.0
# 1    female  group C        some college      standard  completed   69.0
# 2    female  group B     master's degree      standard       none   90.0
# 4      male  group C        some college      standard       none   76.0
# 5    female  group B  associate's degree      standard       none   71.0
# 6    female  group B        some college      standard  completed   88.0
# 8      male  group D         high school  free/reduced  completed   64.0
# 12   female  group B         high school      standard       none   65.0
# 13     male  group A        some college      standard  completed   78.0
# 15   female  group C    some high school      standard       none   69.0
# 16     male  group C         high school      standard       none   88.0
# 20     male  group D         high school      standard       none   66.0
# ...

# %%
passread = df.loc[df['reading'].isin(list(range(x1,x2+1)))]

# %%
passwrite = df.loc[df['writing'].isin(list(range(x1,x2+1)))]

# %%
x0
# Out:
# 0

# %%
passread
# Out:
#      gender     race              parent         lunch  test_prep   math  \
# 0    female  group B   bachelor's degree      standard       none   72.0
# 1    female  group C        some college      standard  completed   69.0
# 2    female  group B     master's degree      standard       none   90.0
# 4      male  group C        some college      standard       none   76.0
# 5    female  group B  associate's degree      standard       none   71.0
# 6    female  group B        some college      standard  completed   88.0
# 8      male  group D         high school  free/reduced  completed   64.0
# 12   female  group B         high school      standard       none   65.0
# 13     male  group A        some college      standard  completed   78.0
# 15   female  group C    some high school      standard       none   69.0
# 16     male  group C         high school      standard       none   88.0
# 20     male  group D         high school      standard       none   66.0
# ...

# %%
passwrite
# Out:
#      gender     race              parent         lunch  test_prep   math  \
# 0    female  group B   bachelor's degree      standard       none   72.0
# 1    female  group C        some college      standard  completed   69.0
# 2    female  group B     master's degree      standard       none   90.0
# 4      male  group C        some college      standard       none   76.0
# 5    female  group B  associate's degree      standard       none   71.0
# 6    female  group B        some college      standard  completed   88.0
# 8      male  group D         high school  free/reduced  completed   64.0
# 12   female  group B         high school      standard       none   65.0
# 13     male  group A        some college      standard  completed   78.0
# 15   female  group C    some high school      standard       none   69.0
# 16     male  group C         high school      standard       none   88.0
# 19   female  group C  associate's degree  free/reduced       none   54.0
# ...

# %%
x0 = 0

# %%
x40 = 40

# %%
float(len(passmath))
# Out:
# 661.0

# %%
objects = ('Math', 'Read', 'Write')
y_pos = np.arange(len(objects))
performance = [float(len(passmath)),float(len(passread)),float(len(passwrite))]
 
plt.bar(y_pos, performance, align='center', alpha=0.6)
plt.xticks(y_pos, objects)
plt.ylabel('Banyak Siswa')
plt.title('Tabel Kelulusan Ujian')
 
plt.show()

# %%
passmath
# Out:
#      gender     race              parent         lunch  test_prep   math  \
# 0    female  group B   bachelor's degree      standard       none   72.0
# 1    female  group C        some college      standard  completed   69.0
# 2    female  group B     master's degree      standard       none   90.0
# 4      male  group C        some college      standard       none   76.0
# 5    female  group B  associate's degree      standard       none   71.0
# 6    female  group B        some college      standard  completed   88.0
# 8      male  group D         high school  free/reduced  completed   64.0
# 12   female  group B         high school      standard       none   65.0
# 13     male  group A        some college      standard  completed   78.0
# 15   female  group C    some high school      standard       none   69.0
# 16     male  group C         high school      standard       none   88.0
# 20     male  group D         high school      standard       none   66.0
# ...

# %%
df.loc[(df["math"]>60) & (df["reading"]>60) & (df["writing"]>60)]
# Out:
#      gender     race              parent         lunch  test_prep   math  \
# 0    female  group B   bachelor's degree      standard       none   72.0
# 1    female  group C        some college      standard  completed   69.0
# 2    female  group B     master's degree      standard       none   90.0
# 4      male  group C        some college      standard       none   76.0
# 5    female  group B  associate's degree      standard       none   71.0
# 6    female  group B        some college      standard  completed   88.0
# 8      male  group D         high school  free/reduced  completed   64.0
# 12   female  group B         high school      standard       none   65.0
# 13     male  group A        some college      standard  completed   78.0
# 15   female  group C    some high school      standard       none   69.0
# 16     male  group C         high school      standard       none   88.0
# 20     male  group D         high school      standard       none   66.0
# ...

# %%
malepassall = df.loc[(df["gender"] == "male") & (df["math"]>60) & (df["reading"]>60) & (df["writing"]>60)]

# %%
fempassall = df.loc[(df["gender"] == "female") & (df["math"]>60) & (df["reading"]>60) & (df["writing"]>60)]

# %%
float(len(fempassall))
# Out:
# 310.0

# %%
float(len(malepassall))
# Out:
# 269.0

# %%
objects = ('Laki-Laki', 'Perempuan')
y_pos = np.arange(len(objects))
performance = [float(len(malepassall)),float(len(fempassall))]
 
plt.bar(y_pos, performance, align='center', alpha=0.6)
plt.xticks(y_pos, objects)
plt.ylabel('Banyak Siswa')
plt.title('Tabel Kelulusan Ujian Berdasarkan Jenis Kelamin')
 
plt.show()

# %%
raceApass = df.loc[(df["race"] == "group A") & (df["math"]>60) & (df["reading"]>60) & (df["writing"]>60)]
raceBpass = df.loc[(df["race"] == "group B") & (df["math"]>60) & (df["reading"]>60) & (df["writing"]>60)]
raceCpass = df.loc[(df["race"] == "group C") & (df["math"]>60) & (df["reading"]>60) & (df["writing"]>60)]
raceDpass = df.loc[(df["race"] == "group D") & (df["math"]>60) & (df["reading"]>60) & (df["writing"]>60)]

# %%
objects = ('A', 'B', 'C', 'D')
y_pos = np.arange(len(objects))
performance = [float(len(raceApass)),float(len(raceBpass)),float(len(raceCpass)),float(len(raceDpass))]
 
plt.bar(y_pos, performance, align='center', alpha=0.6)
plt.xticks(y_pos, objects)
plt.ylabel('Banyak Siswa')
plt.title('Tabel Kelulusan Ujian Berdasarkan Ras')
 
plt.show()

# %%
totalA = df.loc[(df["race"] == "group A")]
totalB = df.loc[(df["race"] == "group B")]
totalC = df.loc[(df["race"] == "group C")]
totalD = df.loc[(df["race"] == "group D")]

# %%
objects = ("A", 'B', "C", 'D')
y_pos = np.arange(len(objects))
performance = [(float(len(raceApass)) *100) / (float(len(totalA))),(float(len(raceBpass)) *100) / 
               (float(len(totalB))),(float(len(raceCpass)) *100) / (float(len(totalC))),(float(len(raceDpass)) *100) 
               / (float(len(totalD)))]
 
plt.bar(y_pos, performance, align='center', alpha=0.6)
plt.xticks(y_pos, objects)
plt.ylabel('Banyak Siswa')
plt.title('Presentasi Kelulusan Ujian Berdasarkan Ras')
 
plt.show()

# %%
parHSpass = df.loc[(df["parent"] == "high school") & (df["math"]>60) & (df["reading"]>60) & (df["writing"]>60)]
parSCpass = df.loc[(df["parent"] == "some college") & (df["math"]>60) & (df["reading"]>60) & (df["writing"]>60)]
parADpass = df.loc[(df["parent"] == "associate's degree") & (df["math"]>60) & (df["reading"]>60) & (df["writing"]>60)]
parBDpass = df.loc[(df["parent"] == "bachelor's degree") & (df["math"]>60) & (df["reading"]>60) & (df["writing"]>60)]
parMDpass = df.loc[(df["parent"] == "master's degree") & (df["math"]>60) & (df["reading"]>60) & (df["writing"]>60)]

# %%
objects = ("H'School", 'Some College', "Associate", 'Bachelor', 'Master')
y_pos = np.arange(len(objects))
performance = [float(len(parHSpass)),float(len(parSCpass)),float(len(parADpass)),float(len(parBDpass)),float(len(parMDpass))]
 
plt.bar(y_pos, performance, align='center', alpha=0.6)
plt.xticks(y_pos, objects)
plt.ylabel('Banyak Siswa')
plt.title('Tabel Kelulusan Ujian Berdasarkan Orang Tua')
 
plt.show()

# %%
totalHS = df.loc[(df["parent"] == "high school")]
totalSC = df.loc[(df["parent"] == "some college")]
totalAD = df.loc[(df["parent"] == "associate's degree")]
totalBD = df.loc[(df["parent"] == "bachelor's degree")]
totalMD = df.loc[(df["parent"] == "master's degree")]

# %%
(float(len(parHSpass)) *100) / (float(len(totalHS)))
# Out:
# 46.93877551020408

# %%
objects = ("SMA", 'Kuliah', "D3", 'S1', 'S2')
y_pos = np.arange(len(objects))
performance = [(float(len(parHSpass)) *100) / (float(len(totalHS))),
               (float(len(parSCpass)) *100) / (float(len(totalSC))),(float(len(parADpass)) *100) / 
               (float(len(totalAD))),(float(len(parBDpass)) *100) / (float(len(totalBD))),(float(len(parMDpass)) 
                                                                                           *100) / (float(len(totalMD)))]
 
plt.bar(y_pos, performance, align='center', alpha=0.6)
plt.xticks(y_pos, objects)
plt.ylabel('Banyak Siswa')
plt.title('Presentasi Kelulusan Ujian Berdasarkan Pendidikan Orang Tua')
 
plt.show()
